# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
women_degrees=pd.read_csv("C:/Users/hp/Downloads/percent-bachelors-degrees-women-usa.csv")

# %%
women_degrees.head(10)
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
# 5  1975    18.333162     19.134048                 60.9  34.449902  19.686249
# 6  1976    22.252760     21.394491                 61.3  36.072871  23.430038
# 7  1977    24.640177     23.740541                 62.0  38.331386  27.163427
# 8  1978    27.146192     25.849240                 62.5  40.112496  30.527519
# 9  1979    29.633365     27.770477                 63.2  42.065551  33.621634
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
# 5                           41.5              19.8  72.801854          3.2
# 6                           44.3              23.9  72.166525          4.5
# 7                           46.9              25.7  72.456395          6.8
# 8                           49.9              28.1  73.192821          8.4
# 9                           52.3              30.2  73.821142          9.4
#
#      English  Foreign Languages  Health Professions  Math and Statistics  \
# 0  65.570923               73.8                77.1                 38.0
# 1  64.556485               73.9                75.5                 39.0
# 2  63.664263               74.6                76.9                 40.2
# 3  62.941502               74.9                77.4                 40.9
# 4  62.413412               75.3                77.9                 41.8
# 5  61.647206               75.0                78.9                 40.7
# 6  62.148194               74.4                79.2                 41.5
# 7  62.723067               74.3                80.5                 41.1
# 8  63.619122               74.3                81.9                 41.6
# 9  65.088390               74.2                82.3                 42.3
#
#    Physical Sciences  Psychology  Public Administration  \
# 0               13.8        44.4                   68.4
# 1               14.9        46.2                   65.5
# 2               14.8        47.6                   62.6
# 3               16.5        50.4                   64.3
# 4               18.2        52.6                   66.1
# 5               19.1        54.5                   63.0
# 6               20.0        56.9                   65.6
# 7               21.3        59.0                   69.3
# 8               22.5        61.3                   71.5
# 9               23.7        63.3                   73.3
#
#    Social Sciences and History
# 0                         36.8
# 1                         36.2
# 2                         36.1
# 3                         36.4
# 4                         37.3
# 5                         37.7
# 6                         39.2
# 7                         40.5
# 8                         41.8
# 9                         43.6

# %%
women_degrees.mean().sort_values()
# Out:
# Engineering                        12.892857
# Computer Science                   25.809524
# Physical Sciences                  31.304762
# Architecture                       33.685540
# Agriculture                        33.848165
# Business                           40.653471
# Math and Statistics                44.478571
# Social Sciences and History        45.407143
# Biology                            49.429864
# Communications and Journalism      56.216667
# Art and Performance                61.100000
# English                            66.186680
# Psychology                         68.776190
# Foreign Languages                  71.723810
# Public Administration              76.085714
# Education                          76.356236
# Health Professions                 82.983333
# Year                             1990.500000
# dtype: float64

# %%
women_degrees.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
plt.plot(women_degrees['Year'],women_degrees['Engineering'],color='b',label='women',linewidth=2)
plt.plot(women_degrees['Year'],100-women_degrees['Engineering'],color='g',label='men',linewidth=2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.tick_params(bottom='off',top='off',right='off',left='off')
plt.title('Percentage of Engineering degrees awarded by year')
plt.show()

# %%
major_cat=['Computer Science','Physical Sciences','Agriculture', 'Architecture']
fig=plt.figure(figsize=(12,4))
for i in range(0,4):
    ax=fig.add_subplot(1,4,i+1)
    ax.plot(women_degrees['Year'],women_degrees[major_cat[i]],c='g',label='women',linewidth=2)
    ax.plot(women_degrees['Year'],100-women_degrees[major_cat[i]],c='r',label='men',linewidth=2)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,85)
    ax.set_title(major_cat[i]) 
    ax.tick_params(bottom='off',top='off',right='off',left='off')
    #ax.text(1970,12,'men')
    #ax.text(1970,75,'women')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
major_cat=['Business','Math and Statistics','Social Sciences and History', 'Biology']
fig=plt.figure(figsize=(12,4))
for i in range(0,4):
    ax=fig.add_subplot(1,4,i+1)
    ax.plot(women_degrees['Year'],women_degrees[major_cat[i]],c='g',label='women',linewidth=2)
    ax.plot(women_degrees['Year'],100-women_degrees[major_cat[i]],c='r',label='men',linewidth=2)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,85)
    ax.set_title(major_cat[i])
    ax.tick_params(bottom='off',top='off',right='off',left='off')
    #ax.text(1970,12,'men')
    #ax.text(1970,75,'women')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
major_cat=['Communications and Journalism','Art and Performance','English','Psychology']
fig=plt.figure(figsize=(12,4))
for i in range(0,4):
    ax=fig.add_subplot(1,4,i+1)
    ax.plot(women_degrees['Year'],women_degrees[major_cat[i]],c='g',label='women',linewidth=2)
    ax.plot(women_degrees['Year'],100-women_degrees[major_cat[i]],c='r',label='men',linewidth=2)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,85)
    ax.set_title(major_cat[i])
    ax.tick_params(bottom='off',top='off',right='off',left='off')
    #ax.text(1970,12,'men')
    #ax.text(1970,75,'women')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
major_cat=['Foreign Languages','Public Administration','Education','Health Professions']
fig=plt.figure(figsize=(12,4))
for i in range(0,4):
    ax=fig.add_subplot(1,4,i+1)
    ax.plot(women_degrees['Year'],women_degrees[major_cat[i]],c='g',label='women',linewidth=2)
    ax.plot(women_degrees['Year'],100-women_degrees[major_cat[i]],c='r',label='men',linewidth=2)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,89)
    ax.set_title(major_cat[i])
    ax.tick_params(bottom='off',top='off',right='off',left='off')
    #ax.text(1970,12,'men')
    #ax.text(1970,75,'women')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
y=women_degrees.set_index("Year")
l=['Agriculture','Psychology','Business','Math and Statistics','Social Sciences and History', 'Biology']
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(1,1,1)
ax.tick_params(bottom='off',top='off',right='off',left='off')
ax.plot(y['Agriculture'],linewidth=2)
ax.plot(y['Business'],linewidth=2)
ax.plot(y['Architecture'],linewidth=2)
ax.plot(y['Physical Sciences'],linewidth=2)
ax.set_ylabel('% Women representation ')
ax.set_xlabel('Years')
ax.set_title('% Women representation over the years')
for key,spine in ax.spines.items():
        spine.set_visible(False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(1,1,1)
ax.tick_params(bottom='off',top='off',right='off',left='off')
ax.plot(y['Computer Science'],linewidth=2)
ax.plot(y['Biology'],linewidth=2)
ax.plot(y['Engineering'],linewidth=2)
ax.plot(y['Math and Statistics'],linewidth=2)
ax.set_ylabel('% Women representation ')
ax.set_xlabel('Years')
ax.set_title('% Women representation over the years')
for key,spine in ax.spines.items():
        spine.set_visible(False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(1,1,1)
ax.tick_params(bottom='off',top='off',right='off',left='off')
ax.plot(100-y['Foreign Languages'],linewidth=2)
ax.plot(100-y['Public Administration'],linewidth=2)
ax.plot(100-y['Education'],linewidth=2)
ax.plot(100-y['Health Professions'],linewidth=2)
ax.set_ylabel('% Men representation ')
ax.set_xlabel('Years')
ax.set_title('% Men representation over the years')
for key,spine in ax.spines.items():
        spine.set_visible(False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
